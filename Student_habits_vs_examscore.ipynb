# %% [markdown]
# Importing the required library

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Loading the dataset

# %%
df=pd.read_csv("student_habits_performance.csv" )
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %% [markdown]
# Removing the unecessary columns which are not important for the analysis

# %%
df1=df.drop(columns=["netflix_hours","part_time_job","diet_quality","exercise_frequency",
                     "parental_education_level","internet_quality","extracurricular_participation"])
df1
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      attendance_percentage  sleep_hours  mental_health_rating  exam_score
# ...

# %% [markdown]
# Checking for any null values in the dataset

# %%
df1.isnull().sum()
# Out:
# student_id               0
# age                      0
# gender                   0
# study_hours_per_day      0
# social_media_hours       0
# attendance_percentage    0
# sleep_hours              0
# mental_health_rating     0
# exam_score               0
# dtype: int64

# %%
df1.dtypes
# Out:
# student_id                object
# age                        int64
# gender                    object
# study_hours_per_day      float64
# social_media_hours       float64
# attendance_percentage    float64
# sleep_hours              float64
# mental_health_rating       int64
# exam_score               float64
# dtype: object

# %%
df1.set_index('student_id',inplace=True)
df1
# Out:
#             age  gender  study_hours_per_day  social_media_hours  \
# student_id
# S1000        23  Female                  0.0                 1.2
# S1001        20  Female                  6.9                 2.8
# S1002        21    Male                  1.4                 3.1
# S1003        23  Female                  1.0                 3.9
# S1004        19  Female                  5.0                 4.4
# ...         ...     ...                  ...                 ...
# S1995        21  Female                  2.6                 0.5
# S1996        17  Female                  2.9                 1.0
# S1997        20    Male                  3.0                 2.6
# S1998        24    Male                  5.4                 4.1
# S1999        19  Female                  4.3                 2.9
#
#             attendance_percentage  sleep_hours  mental_health_rating  \
# student_id
# S1000                        85.0          8.0                     8
# ...

# %% [markdown]
# Saving the cleaned data

# %%
df1.to_csv('cleaned_data.csv',index=True)

# %% [markdown]
# # EDA

# %%
df1.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  \
# count  1000.0000           1000.00000         1000.000000
# mean     20.4980              3.55010            2.505500
# std       2.3081              1.46889            1.172422
# min      17.0000              0.00000            0.000000
# 25%      18.7500              2.60000            1.700000
# 50%      20.0000              3.50000            2.500000
# 75%      23.0000              4.50000            3.300000
# max      24.0000              8.30000            7.200000
#
#        attendance_percentage  sleep_hours  mental_health_rating   exam_score
# count            1000.000000  1000.000000           1000.000000  1000.000000
# mean               84.131700     6.470100              5.438000    69.601500
# std                 9.399246     1.226377              2.847501    16.888564
# min                56.000000     3.200000              1.000000    18.400000
# ...

# %% [markdown]
# Creating a new column where if exam_score was less than 40 it was fail , if it was less than 80 it was Average and above 80 is considered as good .

# %%
def evaluate_result(marks):
    if marks >= 80:
        return 'Good'
    elif marks > 40:
        return 'Average'
    else:
        return 'Fail'

df1['student_performance'] = df1['exam_score'].apply(evaluate_result)
df1
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      attendance_percentage  sleep_hours  mental_health_rating  exam_score  \
# ...

# %% [markdown]
# The graph of the exam score is is left skewed , that shows most of the students scored good marks and fewer students got good marks .

# %%
sns.histplot(df1['exam_score'], kde=True)

# Add vertical lines for mean and quartiles
plt.axvline(x=np.mean(df1['exam_score']), color='red', linestyle="--", label='Mean')
plt.axvline(x=np.percentile(df1['exam_score'], 25), color='green', linestyle="--", label='1st Quartile (25%)')
plt.axvline(x=np.percentile(df1['exam_score'], 75), color='black', linestyle="--", label='3rd Quartile (75%)')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\91947\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Now we will find out the variables that are correlated with exam score using correlation matrix.

# %%
df1.select_dtypes(include=["number"]).corr()
# Out:
#                             age  study_hours_per_day  social_media_hours  \
# age                    1.000000             0.003971           -0.009151
# study_hours_per_day    0.003971             1.000000            0.020282
# social_media_hours    -0.009151             0.020282            1.000000
# attendance_percentage -0.026055             0.026264            0.040479
# sleep_hours            0.037482            -0.027757            0.018236
# mental_health_rating  -0.045101            -0.003768            0.001496
# exam_score            -0.008907             0.825419           -0.166733
#
#                        attendance_percentage  sleep_hours  \
# age                                -0.026055     0.037482
# study_hours_per_day                 0.026264    -0.027757
# social_media_hours                  0.040479     0.018236
# attendance_percentage               1.000000     0.013756
# sleep_hours                         0.013756     1.000000
# ...

# %% [markdown]
# From the above matrix we can infer :
# 1)Age has rarely any effect on exam score  .
# 2)Study hours has strong correlation with exam score.
# 3)Social media hours has a slight  negative correlation with exam score.
# 4)Attendance percentage also has a slight positive correlation with exam score .
# 5)Sleep hours also have a slight positive correlation with exam score.
# 6)Metal health rating  has a slight positive correlation with exam score.

# %%
count_table = pd.crosstab(df1['student_performance'], df1['gender'])

# Show the table
print(count_table)
# Out:
# gender               Female  Male  Other
# student_performance
# Average                 329   321     31
# Fail                     18    24      0
# Good                    134   132     11

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='student_performance', hue='gender', data=df1)

plt.title('Student Performance by Gender')
plt.xlabel('Performance Category')
plt.ylabel('Number of Students')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# Lets find out some of the variables that differ of the student having good, average and fail .

# %%
df2=df1[df1["student_performance"].isin(["Good","Average"])]
df2
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 4        S1004   19  Female                  5.0                 4.4
# 5        S1005   24    Male                  7.2                 1.3
# 6        S1006   21  Female                  5.6                 1.5
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      attendance_percentage  sleep_hours  mental_health_rating  exam_score  \
# ...

# %% [markdown]
# Lets see how is time spent by a student who scores Good or average

# %%
df2.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  \
# count  958.000000           958.000000          958.000000
# mean    20.495825             3.660752            2.482985
# std      2.316062             1.391842            1.178833
# min     17.000000             0.000000            0.000000
# 25%     19.000000             2.700000            1.700000
# 50%     20.000000             3.600000            2.450000
# 75%     23.000000             4.600000            3.200000
# max     24.000000             8.300000            7.200000
#
#        attendance_percentage  sleep_hours  mental_health_rating  exam_score
# count             958.000000   958.000000            958.000000  958.000000
# mean               84.128914     6.478079              5.516701   71.203445
# std                 9.420478     1.222037              2.851466   15.348189
# min                56.000000     3.200000              1.000000   40.300000
# ...

# %%
df3=df1[df1["student_performance"] =="Fail"]
df3.head(10)
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 105      S1105   18    Male                  1.4                 3.9
# 129      S1129   20    Male                  0.3                 4.2
# 165      S1165   17    Male                  0.5                 3.3
# 195      S1195   18  Female                  0.0                 2.8
# 212      S1212   21    Male                  1.4                 2.7
# 265      S1265   18  Female                  0.6                 3.1
# 295      S1295   20  Female                  0.9                 4.3
# 304      S1304   18    Male                  2.6                 3.5
#
#      attendance_percentage  sleep_hours  mental_health_rating  exam_score  \
# 2                     94.8          8.0                     1        34.3
# ...

# %% [markdown]
# let analyse for the students who fail

# %%
df3.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  \
# count  42.000000            42.000000           42.000000
# mean   20.547619             1.026190            3.019048
# std     2.143651             0.737186            0.879922
# min    17.000000             0.000000            1.100000
# 25%    18.500000             0.350000            2.400000
# 50%    21.000000             0.950000            3.100000
# 75%    22.000000             1.400000            3.575000
# max    24.000000             2.700000            4.800000
#
#        attendance_percentage  sleep_hours  mental_health_rating  exam_score
# count              42.000000    42.000000             42.000000   42.000000
# mean               84.195238     6.288095              3.642857   33.061905
# std                 9.009425     1.324111              2.081527    4.855068
# min                62.900000     3.700000              1.000000   18.400000
# ...
